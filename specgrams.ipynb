# %%
# %pylab inline
import utils
import scipy as sp
import numpy as np
d = utils.load_data("./data", pad=False)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['plot']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
for x in d['0'][:4]:
    plt.specgram(x)
    plt.show()

# %%
for x in d['A'][:4]:
    plt.specgram(x)
    plt.show()

# %% [markdown]
# #### The spectra are surprisingly unique considering how bad my recordings are

# %%
# Plot num_per specgrams per letter to compare how they all look
num_per = 3
plots = plt.subplots(len(d), num_per)
plots[0].set_size_inches(20, 12)  # 20 inches across, 12 down
for plot in plots[1].flatten():
    plot.xaxis.set_visible(False)
    plot.yaxis.set_visible(False)
for r, letter in enumerate(d):
    for c, instance in enumerate(d[letter][:num_per]):
        plots[1][r][c].specgram(instance)
plt.show()

# %%
print([k for k in d])
# Out:
# ['A', 'C', 'B', 'D', '1', '0', '3', '2', '5', '4', '7', '6', '9', '8']
